# %%
# !pip install SAGEDbias==0.0.11

from saged import SAGEDData, SourceFinder, Scraper
import pandas as pd
import re
from tqdm import tqdm

domains_and_categories = {
    "nationalities": ["British people", "American people", "Indian people"],
    "religion": ["Christianity", "Islam", "Hinduism", "Atheism"],
    "gender": ["Male", "Female", "Non-binary", "Transgender"],
    "lgbtq": ["Gay", "Lesbian", "Bisexual", "Transgender"],
    "languages": ["English speakers", "Spanish speakers", "Mandarin speakers"],
    "age_groups": ["Children", "Teenagers", "Adults", "Seniors"]
}


rows = []


for domain, categories in tqdm(domains_and_categories.items(), desc="Processing Domains"):
    for category in categories:
        print(f"Processing: {domain} - {category}")

        try:

            keywords_data = SAGEDData.create_data(domain, category, "keywords")

            keywords_to_add = {
                "nationalities": ["Brit", "UK", "USA", "Indian"],
                "religion": ["Faith", "Belief", "God", "Spirituality"],
                "gender": ["He", "She", "They", "Identity"],
                "lgbtq": ["Pride", "Equality", "Love", "Freedom"],
                "languages": ["Speaking", "Fluent", "Native", "Learning"],
                "age_groups": ["Youth", "Adulting", "Mature", "Senior Citizen"],
            }.get(domain, [])

            for keyword in keywords_to_add:
                keywords_data.add(keyword=keyword)
            source_finder = SourceFinder(keywords_data)
            wiki_sources = source_finder.find_scrape_urls_on_wiki(top_n=2, scrape_backlinks=2)

            if not wiki_sources.data:
                print(f"No wiki sources found for category: {category}")
                continue

            scraper = Scraper(wiki_sources)
            scraper.scrape_in_page_for_wiki_with_buffer_files()
            scraped_sentences_data = scraper.scraped_sentence_to_saged_data()

            if not scraped_sentences_data.data:
                print(f"No data found for category: {category}")
                continue
            if 'keywords' not in scraped_sentences_data.data[0]:
                print(f"No keywords data for category: {category}")
                continue

            for keyword, keyword_data in scraped_sentences_data.data[0]['keywords'].items():
                if 'scraped_sentences' not in keyword_data:
                    print(f"No scraped sentences for keyword: {keyword}")
                    continue

                scraped_sentences = keyword_data.get('scraped_sentences', [])
                for sentence, _ in scraped_sentences:
                    stereotype_type = domain.capitalize()
                    category_label = category
                    label = "Biased" if domain in ["nationalities", "gender", "lgbtq", "age_groups"] else "Neutral"

                    marked_text = sentence
                    for word in keywords_to_add:
                        marked_text = re.sub(r'\b' + re.escape(word) + r'\b', f'==={word}===', marked_text, flags=re.IGNORECASE)

                    rows.append({
                        'stereotype_type': stereotype_type,
                        'text': sentence,
                        'text_with_marker': marked_text,
                        'category': category_label,
                        'data_source': 'scraped_wikipedia',
                        'label': label
                    })

        except Exception as e:
            print(f"Error processing {domain} - {category}: {e}")
            continue

df = pd.DataFrame(rows)
output_file = "scraped_bias_dataset.csv"
df.to_csv(output_file, index=False)
print(f"Scraped and processed data saved to '{output_file}'")
# Out:
# Requirement already satisfied: SAGEDbias==0.0.11 in /usr/local/lib/python3.10/dist-packages (0.0.11)
# Requirement already satisfied: bs4<0.0.3,>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (0.0.2)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (3.9.1)
# Requirement already satisfied: numpy<2.0.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (2.2.2)
# Requirement already satisfied: plotly<6.0.0,>=5.23.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (5.24.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (2.32.3)
# Requirement already satisfied: scikit-learn<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (1.13.1)
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (2.7.0)
# Requirement already satisfied: spacy<4.0.0,>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (3.7.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.4 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (4.66.6)
# Requirement already satisfied: transformers<5.0.0,>=4.11.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (4.46.2)
# Requirement already satisfied: wikipedia-api<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (0.6.9)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4<0.0.3,>=0.0.2->SAGEDbias==0.0.11) (4.12.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->SAGEDbias==0.0.11) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->SAGEDbias==0.0.11) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->SAGEDbias==0.0.11) (2024.9.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.23.0->SAGEDbias==0.0.11) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.23.0->SAGEDbias==0.0.11) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0,>=1.0->SAGEDbias==0.0.11) (3.5.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (11.0.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.13.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (3.16.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (0.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (4.12.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (7.0.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4<0.0.3,>=0.0.2->SAGEDbias==0.0.11) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.1.2)
# Processing Domains:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing: nationalities - British people
# Searching Wikipedia for topic: British people
# Found Wikipedia page: British people
# Searching similar forelinks for British people
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  7.52it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  7.93it/s]
# Searching similar backlinks for British people
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  9.11it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  7.00it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:02,  1.04keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.16keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:02<00:00,  1.21keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.05keyword/s]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:03<00:07,  3.81s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  3.10keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  2.97keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  3.02keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  3.01keyword/s]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:05<00:02,  2.36s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  1.61keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.60keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  1.59keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.31keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:08<00:00,  2.74s/url]
# Processing: nationalities - American people
# Searching Wikipedia for topic: American people
# Found Wikipedia page: Americans
# Searching similar forelinks for American people
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  9.48it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  8.03it/s]
# Searching similar backlinks for American people
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  7.43it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  5.50it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  6.63keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  6.39keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  6.33keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  6.30keyword/s]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:00<00:01,  1.56url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:02,  1.24keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:02<00:02,  1.05s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:02<00:00,  1.06keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.10keyword/s]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:04<00:02,  2.41s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.96keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  3.02keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  2.95keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  2.94keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:05<00:00,  1.89s/url]
# Error processing nationalities - American people: 'scraped_sentences'
# Processing: nationalities - Indian people
# Searching Wikipedia for topic: Indian people
# Found Wikipedia page: Indian people
# Searching similar forelinks for Indian people
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  9.46it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  7.56it/s]
# Searching similar backlinks for Indian people
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  9.04it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  8.23it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:01<00:05,  1.71s/keyword]
#
# Scraping in page:  50%|█████     | 2/4 [00:03<00:02,  1.48s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:04<00:01,  1.33s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:05<00:00,  1.39s/keyword]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:05<00:11,  5.57s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:02,  1.11keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.11keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:03<00:01,  1.13s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:04<00:00,  1.03s/keyword]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:09<00:04,  4.72s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  1.75keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.78keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  1.76keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:02<00:00,  1.42keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:12<00:00,  4.18s/url]
# Processing Domains:  17%|█▋        | 1/6 [03:47<18:59, 227.91s/it]
# Error processing nationalities - Indian people: 'scraped_sentences'
# Processing: religion - Christianity
# Searching Wikipedia for topic: Christianity
# Found Wikipedia page: Christianity
# Searching similar forelinks for Christianity
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  8.02it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  7.80it/s]
# Searching similar backlinks for Christianity
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  1.22it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  2.13it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  4.13keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  4.02keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  3.93keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  3.92keyword/s]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:01<00:02,  1.03s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:01<00:05,  1.81s/keyword]
#
# Scraping in page:  50%|█████     | 2/4 [00:03<00:03,  1.56s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:05<00:01,  1.71s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:06<00:00,  1.62s/keyword]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:07<00:04,  4.25s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.92keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  2.90keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  2.52keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  2.48keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:09<00:00,  3.05s/url]
# Processing: religion - Islam
# Searching Wikipedia for topic: Islam
# Found Wikipedia page: Islam
# Searching similar forelinks for Islam
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  5.28it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  6.56it/s]
# Searching similar backlinks for Islam
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  2.11it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:01<00:00,  1.90it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  3.00keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  2.90keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  2.89keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  2.86keyword/s]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:01<00:02,  1.41s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:01<00:03,  1.20s/keyword]
#
# Scraping in page:  50%|█████     | 2/4 [00:02<00:02,  1.20s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:04<00:01,  1.43s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:05<00:00,  1.32s/keyword]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:06<00:03,  3.70s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:02,  1.15keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:02<00:02,  1.20s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:03<00:01,  1.06s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:04<00:00,  1.02s/keyword]
#
# Scraping through URL: 100%|██████████| 3/3 [00:10<00:00,  3.61s/url]
# Processing: religion - Hinduism
# Searching Wikipedia for topic: Hinduism
# Found Wikipedia page: Hinduism
# Searching similar forelinks for Hinduism
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  7.45it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  8.04it/s]
# Searching similar backlinks for Hinduism
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  1.67it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  2.66it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:01<00:05,  1.90s/keyword]
#
# Scraping in page:  50%|█████     | 2/4 [00:03<00:03,  1.66s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:05<00:01,  1.81s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:06<00:00,  1.72s/keyword]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:06<00:13,  6.88s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  4.32keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  4.24keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  4.17keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  4.17keyword/s]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:07<00:03,  3.40s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:01<00:04,  1.42s/keyword]
#
# Scraping in page:  50%|█████     | 2/4 [00:02<00:02,  1.07s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:03<00:01,  1.11s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:05<00:00,  1.31s/keyword]
#
# Scraping through URL: 100%|██████████| 3/3 [00:13<00:00,  4.37s/url]
# Processing: religion - Atheism
# Searching Wikipedia for topic: Atheism
# Found Wikipedia page: Atheism
# Searching similar forelinks for Atheism
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  5.43it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  5.72it/s]
# Searching similar backlinks for Atheism
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  9.47it/s]
#
# Scraping through URL:   0%|          | 0/5 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  4.63keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  4.47keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  4.15keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  4.21keyword/s]
#
# Scraping through URL:  20%|██        | 1/5 [00:00<00:03,  1.04url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  4.84keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  4.95keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  4.99keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  4.92keyword/s]
#
# Scraping through URL:  40%|████      | 2/5 [00:01<00:02,  1.14url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:02,  1.30keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.31keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:02<00:00,  1.00keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.12keyword/s]
#
# Scraping through URL:  60%|██████    | 3/5 [00:05<00:04,  2.11s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:02,  1.20keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.20keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:03<00:01,  1.06s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.04keyword/s]
#
# Scraping through URL:  80%|████████  | 4/5 [00:09<00:02,  2.80s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  3.41keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  3.32keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  3.34keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  3.33keyword/s]
#
# Scraping through URL: 100%|██████████| 5/5 [00:10<00:00,  2.09s/url]
# Processing Domains:  33%|███▎      | 2/6 [29:43<1:07:15, 1008.80s/it]
# Processing: gender - Male
# Searching Wikipedia for topic: Male
# Found Wikipedia page: Male
# Searching similar forelinks for Male
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  6.80it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  6.35it/s]
# Searching similar backlinks for Male
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  8.77it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  8.22it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.38keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  2.32keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  2.34keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  2.34keyword/s]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:01<00:03,  1.72s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.59keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  2.56keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  2.53keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:02<00:00,  1.95keyword/s]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:03<00:01,  1.92s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  3.23keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  3.21keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  3.20keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  3.16keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:05<00:00,  1.69s/url]
# Processing: gender - Female
# Searching Wikipedia for topic: Female
# Found Wikipedia page: Female
# Searching similar forelinks for Female
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  5.81it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  5.97it/s]
# Searching similar backlinks for Female
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  3.55it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  4.72it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:02,  1.37keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:02,  1.00s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:02<00:00,  1.14keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.07keyword/s]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:03<00:07,  3.75s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  3.76keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  3.47keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  3.58keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  3.55keyword/s]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:04<00:02,  2.21s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.18keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  2.65keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  2.87keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  2.79keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:06<00:00,  2.12s/url]
# Processing: gender - Non-binary
# Searching Wikipedia for topic: Non-binary
# Found Wikipedia page: Non-binary gender
# Searching similar forelinks for Non-binary
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  9.82it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  9.21it/s]
# Searching similar backlinks for Non-binary
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  5.94it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  6.00it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:01<00:04,  1.39s/keyword]
#
# Scraping in page:  50%|█████     | 2/4 [00:02<00:02,  1.10s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:03<00:01,  1.02s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.01keyword/s]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:03<00:07,  3.98s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  1.59keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.11keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:02<00:00,  1.29keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:02<00:00,  1.35keyword/s]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:06<00:03,  3.39s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  5.07keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  4.83keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  4.68keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  4.71keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:07<00:00,  2.61s/url]
# Processing: gender - Transgender
# Searching Wikipedia for topic: Transgender
# Found Wikipedia page: Transgender
# Searching similar forelinks for Transgender
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  3.48it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  4.80it/s]
# Searching similar backlinks for Transgender
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  2.72it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  2.61it/s]
#
# Scraping through URL:   0%|          | 0/2 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:01<00:03,  1.09s/keyword]
#
# Scraping in page:  50%|█████     | 2/4 [00:02<00:02,  1.14s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:03<00:01,  1.11s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:04<00:00,  1.15s/keyword]
#
# Scraping through URL:  50%|█████     | 1/2 [00:04<00:04,  4.61s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.24keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  2.23keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  2.20keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  2.21keyword/s]
#
# Scraping through URL: 100%|██████████| 2/2 [00:06<00:00,  3.22s/url]
# Processing Domains:  50%|█████     | 3/6 [34:36<34:06, 682.18s/it]
# Processing: lgbtq - Gay
# Searching Wikipedia for topic: Gay
# Found Wikipedia page: Gay
# Searching similar forelinks for Gay
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  3.83it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  4.69it/s]
# Searching similar backlinks for Gay
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  8.27it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  5.60it/s]
#
# Scraping through URL:   0%|          | 0/4 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:01<00:04,  1.38s/keyword]
#
# Scraping in page:  50%|█████     | 2/4 [00:02<00:02,  1.08s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:03<00:00,  1.01keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.00keyword/s]
#
# Scraping through URL:  25%|██▌       | 1/4 [00:04<00:12,  4.00s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:02,  1.08keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.58keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  1.85keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:02<00:00,  1.79keyword/s]
#
# Scraping through URL:  50%|█████     | 2/4 [00:06<00:05,  2.97s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  4.05keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  4.00keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  3.99keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  3.95keyword/s]
#
# Scraping through URL:  75%|███████▌  | 3/4 [00:07<00:02,  2.08s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  1.52keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:02,  1.04s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:02<00:01,  1.00s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.01keyword/s]
#
# Scraping through URL: 100%|██████████| 4/4 [00:11<00:00,  2.81s/url]
# Processing: lgbtq - Lesbian
# Searching Wikipedia for topic: Lesbian
# Found Wikipedia page: Lesbian
# Searching similar forelinks for Lesbian
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  9.62it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  8.67it/s]
# Searching similar backlinks for Lesbian
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  4.66it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  4.17it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  4.41keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  4.23keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  4.22keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  4.21keyword/s]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:00<00:01,  1.05url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:01<00:03,  1.24s/keyword]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.06keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:02<00:00,  1.18keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.15keyword/s]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:04<00:02,  2.44s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.89keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  3.77keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  4.20keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  3.96keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:05<00:00,  1.82s/url]
# Processing: lgbtq - Bisexual
# Searching Wikipedia for topic: Bisexual
# Found Wikipedia page: Bisexuality
# Searching similar forelinks for Bisexual
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  8.34it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  8.11it/s]
# Searching similar backlinks for Bisexual
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  3.26it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  3.88it/s]
#
# Scraping through URL:   0%|          | 0/2 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  3.05keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  3.11keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  3.20keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  3.18keyword/s]
#
# Scraping through URL:  50%|█████     | 1/2 [00:01<00:01,  1.27s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:02,  1.47keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.46keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:02<00:00,  1.12keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.16keyword/s]
#
# Scraping through URL: 100%|██████████| 2/2 [00:04<00:00,  2.37s/url]
# Processing: lgbtq - Transgender
# Searching Wikipedia for topic: Transgender
# Found Wikipedia page: Transgender
# Searching similar forelinks for Transgender
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  8.12it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  7.65it/s]
# Searching similar backlinks for Transgender
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  3.83it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  3.01it/s]
#
# Scraping through URL:   0%|          | 0/2 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:02,  1.20keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:02<00:02,  1.13s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:03<00:00,  1.00keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.04keyword/s]
#
# Scraping through URL:  50%|█████     | 1/2 [00:03<00:03,  3.85s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.24keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  2.16keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  2.15keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:02<00:00,  1.52keyword/s]
#
# Scraping through URL: 100%|██████████| 2/2 [00:06<00:00,  3.25s/url]
# Processing Domains:  67%|██████▋   | 4/6 [38:53<17:08, 514.16s/it]
# Processing: languages - English speakers
# Searching Wikipedia for topic: English speakers
# Found Wikipedia page: English language
# Searching similar forelinks for English speakers
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  6.37it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  5.68it/s]
# Searching similar backlinks for English speakers
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  1.43it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:01<00:00,  1.89it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:01<00:03,  1.07s/keyword]
#
# Scraping in page:  50%|█████     | 2/4 [00:02<00:02,  1.29s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:03<00:01,  1.18s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:05<00:00,  1.28s/keyword]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:05<00:10,  5.12s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  1.79keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.71keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  1.72keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:02<00:00,  1.73keyword/s]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:07<00:03,  3.48s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  3.90keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  3.77keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  3.77keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  3.78keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:08<00:00,  2.84s/url]
# Processing: languages - Spanish speakers
# Searching Wikipedia for topic: Spanish speakers
# Found Wikipedia page: Hispanophone
# Searching similar forelinks for Spanish speakers
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  6.71it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  7.29it/s]
# Searching similar backlinks for Spanish speakers
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  7.42it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  7.17it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  1.98keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.17keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:02<00:00,  1.44keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:02<00:00,  1.53keyword/s]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:02<00:05,  2.62s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:02,  1.00keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:02<00:02,  1.26s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:03<00:01,  1.18s/keyword]
#
# Scraping in page: 100%|██████████| 4/4 [00:05<00:00,  1.25s/keyword]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:07<00:04,  4.03s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.03keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:01<00:01,  1.20keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  1.57keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:02<00:00,  1.70keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:10<00:00,  3.33s/url]
# Processing Domains:  83%|████████▎ | 5/6 [1:03:44<14:26, 866.28s/it]
# Processing: languages - Mandarin speakers
# Searching Wikipedia for topic: Mandarin speakers
# Error processing languages - Mandarin speakers: too many values to unpack (expected 2)
# Processing: age_groups - Children
# Searching Wikipedia for topic: Children
# Found Wikipedia page: Child
# Searching similar forelinks for Children
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  7.63it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  7.87it/s]
# Searching similar backlinks for Children
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  4.18it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s]
#
# Scraping through URL:   0%|          | 0/2 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.13keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  2.09keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  2.11keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  2.03keyword/s]
#
# Scraping through URL:  50%|█████     | 1/2 [00:01<00:01,  1.98s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  5.43keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  5.44keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  5.22keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  5.28keyword/s]
#
# Scraping through URL: 100%|██████████| 2/2 [00:02<00:00,  1.38s/url]
# Processing: age_groups - Teenagers
# Searching Wikipedia for topic: Teenagers
# Found Wikipedia page: Adolescence
# Searching similar forelinks for Teenagers
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  7.65it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  8.22it/s]
# Searching similar backlinks for Teenagers
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  7.74it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  6.31it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:01<00:03,  1.22s/keyword]
#
# Scraping in page:  50%|█████     | 2/4 [00:02<00:02,  1.03s/keyword]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:03<00:00,  1.02keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:03<00:00,  1.04keyword/s]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:03<00:07,  3.85s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  6.02keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  6.19keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  6.22keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  6.14keyword/s]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:04<00:01,  1.97s/url]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.99keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  2.99keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  1.77keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  2.16keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:06<00:00,  2.13s/url]
# Processing: age_groups - Adults
# Searching Wikipedia for topic: Adults
# Found Wikipedia page: Adult
# Searching similar forelinks for Adults
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  6.74it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  6.82it/s]
# Searching similar backlinks for Adults
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  9.51it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  6.29it/s]
#
# Scraping through URL:   0%|          | 0/2 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  4.13keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  4.10keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  4.10keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  4.07keyword/s]
#
# Scraping through URL:  50%|█████     | 1/2 [00:00<00:00,  1.01url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:01,  2.91keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  2.94keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:01<00:00,  2.90keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:01<00:00,  2.88keyword/s]
#
# Scraping through URL: 100%|██████████| 2/2 [00:02<00:00,  1.20s/url]
# Processing: age_groups - Seniors
# Searching Wikipedia for topic: Seniors
# Found Wikipedia page: Senior
# Searching similar forelinks for Seniors
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  9.40it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  7.90it/s]
# Searching similar backlinks for Seniors
# Depth 1/1:   0%|          | 0/2 [00:00<?, ?it/s]
# Depth 1/1:  50%|█████     | 1/2 [00:00<00:00,  8.81it/s]
# Depth 1/1: 100%|██████████| 2/2 [00:00<00:00,  8.51it/s]
#
# Scraping through URL:   0%|          | 0/3 [00:00<?, ?url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  3.24keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  4.21keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  4.66keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  4.55keyword/s]
#
# Scraping through URL:  33%|███▎      | 1/3 [00:00<00:01,  1.12url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  4.28keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  4.19keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  4.19keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  4.17keyword/s]
#
# Scraping through URL:  67%|██████▋   | 2/3 [00:01<00:00,  1.06url/s]
#
# Scraping in page:   0%|          | 0/4 [00:00<?, ?keyword/s]
#
# Scraping in page:  25%|██▌       | 1/4 [00:00<00:00,  3.58keyword/s]
#
# Scraping in page:  50%|█████     | 2/4 [00:00<00:00,  3.86keyword/s]
#
# Scraping in page:  75%|███████▌  | 3/4 [00:00<00:00,  4.27keyword/s]
#
# Scraping in page: 100%|██████████| 4/4 [00:00<00:00,  4.25keyword/s]
#
# Scraping through URL: 100%|██████████| 3/3 [00:02<00:00,  1.06url/s]
# Processing Domains: 100%|██████████| 6/6 [1:05:03<00:00, 650.56s/it]
# Error processing age_groups - Seniors: 'scraped_sentences'
# Scraped and processed data saved to 'scraped_bias_dataset.csv'

# %%
# !pip install SAGEDbias==0.0.11
# Out:
# Requirement already satisfied: SAGEDbias==0.0.11 in /usr/local/lib/python3.10/dist-packages (0.0.11)
# Requirement already satisfied: bs4<0.0.3,>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (0.0.2)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (3.9.1)
# Requirement already satisfied: numpy<2.0.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (2.2.2)
# Requirement already satisfied: plotly<6.0.0,>=5.23.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (5.24.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (2.32.3)
# Requirement already satisfied: scikit-learn<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (1.13.1)
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (2.7.0)
# Requirement already satisfied: spacy<4.0.0,>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (3.7.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.4 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (4.66.6)
# Requirement already satisfied: transformers<5.0.0,>=4.11.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (4.46.2)
# Requirement already satisfied: wikipedia-api<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (0.6.9)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4<0.0.3,>=0.0.2->SAGEDbias==0.0.11) (4.12.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->SAGEDbias==0.0.11) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->SAGEDbias==0.0.11) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->SAGEDbias==0.0.11) (2024.9.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.23.0->SAGEDbias==0.0.11) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.23.0->SAGEDbias==0.0.11) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0,>=1.0->SAGEDbias==0.0.11) (3.5.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (11.0.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.13.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (3.16.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (0.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (4.12.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (7.0.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4<0.0.3,>=0.0.2->SAGEDbias==0.0.11) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.1.2)

# %%
# !pip install SAGEDbias==0.0.11
# !pip install transformers
# !pip install docling
# !pip install ollama

import os
import pandas as pd
from saged import KeywordFinder, SourceFinder, Scraper, SAGEDData
from transformers import pipeline
import re
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor
import time
from functools import wraps

# Step 1: Define race-related domains and categories
domains_and_categories = {
    "race_ethnicity": [
        "White people",
        "Black people",
        "Asian people",
        "Hispanic people",
        "Native American people",
        "Middle Eastern people",
        "African people",
        "European people",
        "Mixed race people"
    ]
}

# Race list for generating and highlighting keywords
race_list = [
    "White", "Black", "Asian", "Hispanic",
    "Native American", "Middle Eastern",
    "African", "European", "Mixed"
]

# Step 2: Define LLM-based keyword generation class
class HuggingFaceChatPipeline:
    def __init__(self, model_name="Qwen/Qwen2.5-1.5B-Instruct"):
        self.chat_pipeline = pipeline(
            "text-generation",
            model=model_name,
            tokenizer=model_name,
            device_map="auto",
            torch_dtype="auto"
        )

    def invoke(self, user_prompt, system_prompt="You are a helpful assistant."):
        prompt = f"{system_prompt}\n\nUser: {user_prompt}\n\nAssistant:"
        response = self.chat_pipeline(
            prompt,
            max_length=512,
            num_return_sequences=1,
            pad_token_id=self.chat_pipeline.tokenizer.eos_token_id
        )[0]["generated_text"]
        response_cleaned = response.replace(prompt, "").strip()
        return response_cleaned

# Step 3: Retry Logic for Resilient Scraping
def retry(max_attempts, delay):
    def decorator(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            for attempt in range(max_attempts):
                try:
                    return func(*args, **kwargs)
                except Exception as e:
                    if attempt < max_attempts - 1:
                        time.sleep(delay)
                    else:
                        raise e
        return wrapper
    return decorator

@retry(max_attempts=3, delay=5)
def safe_scrape(scraper):
    scraper.scrape_in_page_for_wiki_with_buffer_files()

# Step 4: Processing Function
def process_category(category, domain, race_list, model):
    rows = []
    try:
        keyword_finder = KeywordFinder(category, domain)

        # Generate Keywords
        keyword_finder.find_keywords_by_embedding_on_wiki(n_keywords=3)
        keywords_data_embeddings = keyword_finder.keywords_to_saged_data()

        keyword_finder.find_keywords_by_llm_inquiries(
            generation_function=model.invoke, n_keywords=3, n_run=2
        )
        keywords_data_llm = keyword_finder.keywords_to_saged_data()

        # Combine keywords
        keywords_data = keywords_data_embeddings.merge(merge_list=[keywords_data_llm])

        # Scrape Sources
        source_finder = SourceFinder(keywords_data)
        wiki_sources = source_finder.find_scrape_urls_on_wiki(top_n=2, scrape_backlinks=0)

        if not wiki_sources.data:
            print(f"No wiki sources found for category: {category}")
            return rows

        scraper = Scraper(wiki_sources)
        safe_scrape(scraper)
        scraped_sentences_data = scraper.scraped_sentence_to_saged_data()

        # Process Scraped Sentences
        for keyword, keyword_data in scraped_sentences_data.data[0]["keywords"].items():
            scraped_sentences = keyword_data.get("scraped_sentences", [])
            for sentence, _ in scraped_sentences:
                marked_text = sentence
                for word in race_list:
                    marked_text = re.sub(rf"\b{re.escape(word)}\b", f"==={word}===", marked_text, flags=re.IGNORECASE)

                rows.append({
                    "stereotype_type": domain.capitalize(),
                    "text": sentence,
                    "text_with_marker": marked_text,
                    "category": category,
                    "data_source": "scraped_wikipedia",
                    "label": "Biased"
                })
    except Exception as e:
        print(f"Error processing category {category}: {e}")
    return rows

# Step 5: Main Script with Parallel Processing
def main():
    model = HuggingFaceChatPipeline(model_name="Qwen/Qwen2.5-1.5B-Instruct")
    all_rows = []

    with ThreadPoolExecutor(max_workers=4) as executor:  # Adjust max_workers based on your CPU
        futures = [
            executor.submit(process_category, category, domain, race_list, model)
            for domain, categories in domains_and_categories.items()
            for category in categories
        ]
        for future in tqdm(futures, desc="Processing categories"):
            all_rows.extend(future.result())

    # Save results to CSV
    output_file = "optimized_race_bias_dataset.csv"
    df = pd.DataFrame(all_rows)
    df.to_csv(output_file, index=False)
    print(f"Dataset saved to '{output_file}'.")

if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: SAGEDbias==0.0.11 in /usr/local/lib/python3.10/dist-packages (0.0.11)
# Requirement already satisfied: bs4<0.0.3,>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (0.0.2)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (3.9.1)
# Requirement already satisfied: numpy<2.0.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (2.2.2)
# Requirement already satisfied: plotly<6.0.0,>=5.23.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (5.24.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (2.32.3)
# Requirement already satisfied: scikit-learn<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (1.13.1)
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (2.7.0)
# Requirement already satisfied: spacy<4.0.0,>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (3.7.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.4 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (4.66.6)
# Requirement already satisfied: transformers<5.0.0,>=4.11.3 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (4.46.2)
# Requirement already satisfied: wikipedia-api<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from SAGEDbias==0.0.11) (0.6.9)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4<0.0.3,>=0.0.2->SAGEDbias==0.0.11) (4.12.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->SAGEDbias==0.0.11) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->SAGEDbias==0.0.11) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->SAGEDbias==0.0.11) (2024.9.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.23.0->SAGEDbias==0.0.11) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.23.0->SAGEDbias==0.0.11) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->SAGEDbias==0.0.11) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0,>=1.0->SAGEDbias==0.0.11) (3.5.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (10.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.12.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (3.16.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.11.3->SAGEDbias==0.0.11) (0.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (4.12.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.0->SAGEDbias==0.0.11) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers<3.0.0,>=2.1.0->SAGEDbias==0.0.11) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (7.0.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4<0.0.3,>=0.0.2->SAGEDbias==0.0.11) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.2.1->SAGEDbias==0.0.11) (0.1.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: docling in /usr/local/lib/python3.10/dist-packages (2.7.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from docling) (4.12.3)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.10/dist-packages (from docling) (2024.8.30)
# Requirement already satisfied: deepsearch-glm<0.27.0,>=0.26.1 in /usr/local/lib/python3.10/dist-packages (from docling) (0.26.1)
# Requirement already satisfied: docling-core<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from docling) (2.4.1)
# Requirement already satisfied: docling-ibm-models<3.0.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from docling) (2.0.6)
# Requirement already satisfied: docling-parse<3.0.0,>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from docling) (2.1.2)
# Requirement already satisfied: easyocr<2.0,>=1.7 in /usr/local/lib/python3.10/dist-packages (from docling) (1.7.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from docling) (1.2.0)
# Requirement already satisfied: huggingface_hub<1,>=0.23 in /usr/local/lib/python3.10/dist-packages (from docling) (0.26.2)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from docling) (2.1.2)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.10/dist-packages (from docling) (3.1.5)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from docling) (2.2.2)
# Requirement already satisfied: pyarrow<17.0.0,>=16.1.0 in /usr/local/lib/python3.10/dist-packages (from docling) (16.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from docling) (2.9.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from docling) (2.6.1)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from docling) (4.30.0)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from docling) (1.1.2)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from docling) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.10/dist-packages (from docling) (2.32.3)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from docling) (1.3.0)
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from docling) (1.13.1)
# Requirement already satisfied: typer<0.13.0,>=0.12.5 in /usr/local/lib/python3.10/dist-packages (from docling) (0.12.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (2.6)
# Requirement already satisfied: docutils!=0.21 in /usr/local/lib/python3.10/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (0.21.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26.4 in /usr/local/lib/python3.10/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (1.26.4)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (1.0.1)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /usr/local/lib/python3.10/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (13.9.4)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from deepsearch-glm<0.27.0,>=0.26.1->docling) (4.66.6)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from docling-core<3.0.0,>=2.4.0->docling) (1.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /usr/local/lib/python3.10/dist-packages (from docling-core<3.0.0,>=2.4.0->docling) (4.23.0)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /usr/local/lib/python3.10/dist-packages (from docling-core<3.0.0,>=2.4.0->docling) (10.4.0)
# Requirement already satisfied: jsonlines<4.0.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models<3.0.0,>=2.0.6->docling) (3.1.0)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.6.0.66 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models<3.0.0,>=2.0.6->docling) (4.10.0.84)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models<3.0.0,>=2.0.6->docling) (2.5.1+cu121)
# Requirement already satisfied: torchvision<1,>=0 in /usr/local/lib/python3.10/dist-packages (from docling-ibm-models<3.0.0,>=2.0.6->docling) (0.20.1+cu121)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from easyocr<2.0,>=1.7->docling) (0.24.0)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.10/dist-packages (from easyocr<2.0,>=1.7->docling) (0.6.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from easyocr<2.0,>=1.7->docling) (6.0.2)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from easyocr<2.0,>=1.7->docling) (2.0.6)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.10/dist-packages (from easyocr<2.0,>=1.7->docling) (1.3.0.post6)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from easyocr<2.0,>=1.7->docling) (1.11.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1,>=0.23->docling) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1,>=0.23->docling) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1,>=0.23->docling) (24.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1,>=0.23->docling) (4.12.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl<4.0.0,>=3.1.5->docling) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.0->docling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.0.0->docling) (2.23.4)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx<2.0.0,>=1.1.2->docling) (5.3.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx<2.0.0,>=1.0.2->docling) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->docling) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->docling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.3->docling) (2.2.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13.0,>=0.12.5->docling) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13.0,>=0.12.5->docling) (1.5.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines<4.0.0,>=3.1.0->docling-ibm-models<3.0.0,>=2.0.6->docling) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.4.0->docling) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.4.0->docling) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.4.0->docling) (0.21.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.4->docling) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm<0.27.0,>=0.26.1->docling) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm<0.27.0,>=0.26.1->docling) (2.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling) (1.3.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (0.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->deepsearch-glm<0.27.0,>=0.26.1->docling) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=2.2.2->docling-ibm-models<3.0.0,>=2.0.6->docling) (3.0.2)
# Requirement already satisfied: ollama in /usr/local/lib/python3.10/dist-packages (0.4.1)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from ollama) (0.27.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from ollama) (2.9.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.0->ollama) (4.12.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<0.28.0,>=0.27.0->ollama) (1.2.2)
# Initiating the embedding model...Initiating the embedding model...
# Initiating the embedding model...
#
# Initiating the embedding model...
# Processing categories:   0%|          | 0/9 [00:00<?, ?it/s]
# Batches:   0%|          | 0/13 [00:00<?, ?it/s]
# Batches:   0%|          | 0/64 [00:00<?, ?it/s]
# Batches:   0%|          | 0/89 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/41 [00:00<?, ?it/s]
# Calculating similarities:   0%|          | 0/404 [00:00<?, ?it/s]
# Calculating similarities:  33%|███▎      | 133/404 [00:00<00:00, 1329.92it/s]
# Calculating similarities:  66%|██████▌   | 266/404 [00:00<00:00, 1229.23it/s]
# Calculating similarities: 100%|██████████| 404/404 [00:00<00:00, 1116.26it/s]
# /usr/local/lib/python3.10/dist-packages/saged/_scrape.py:185: UserWarning: Model name not provided. Using the default model name 'user_LLM'
#   warnings.warn("Model name not provided. Using the default model name 'user_LLM'")
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating similarities:   0%|          | 0/1284 [00:00<?, ?it/s]
# Calculating similarities:  11%|█         | 136/1284 [00:00<00:00, 1349.96it/s]
# Calculating similarities:  21%|██        | 271/1284 [00:00<00:00, 1112.88it/s]
# Calculating similarities:  34%|███▍      | 434/1284 [00:00<00:00, 1321.33it/s]
# Calculating similarities:  44%|████▍     | 570/1284 [00:00<00:00, 1285.56it/s]
# Calculating similarities:  55%|█████▍    | 701/1284 [00:00<00:00, 1273.28it/s]
# Calculating similarities:  65%|██████▍   | 830/1284 [00:00<00:00, 1203.63it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating similarities:  74%|███████▍  | 952/1284 [00:00<00:00, 1128.77it/s]
#
# Calculating similarities:   0%|          | 0/2043 [00:00<?, ?it/s]
# Calculating similarities:  84%|████████▍ | 1079/1284 [00:00<00:00, 1157.47it/s]
#
# Calculating similarities:   6%|▌         | 122/2043 [00:00<00:01, 1214.36it/s]
# Calculating similarities:  93%|█████████▎| 1196/1284 [00:01<00:00, 1062.23it/s]
#
# Calculating similarities: 100%|██████████| 1284/1284 [00:01<00:00, 1152.54it/s]
# /usr/local/lib/python3.10/dist-packages/saged/_scrape.py:185: UserWarning: Model name not provided. Using the default model name 'user_LLM'
#   warnings.warn("Model name not provided. Using the default model name 'user_LLM'")
#
#
# Calculating similarities:  18%|█▊        | 359/2043 [00:00<00:01, 1086.71it/s]
#
# Calculating similarities:  23%|██▎       | 477/2043 [00:00<00:01, 1116.60it/s]
#
# Calculating similarities:  29%|██▉       | 589/2043 [00:00<00:01, 1102.52it/s]
#
# Calculating similarities:  34%|███▍      | 703/2043 [00:00<00:01, 1107.73it/s]
#
# Calculating similarities:  41%|████      | 839/2043 [00:00<00:01, 1181.82it/s]
#
# Calculating similarities:  47%|████▋     | 960/2043 [00:00<00:00, 1190.34it/s]
#
# Calculating similarities:  54%|█████▍    | 1105/2043 [00:00<00:00, 1269.97it/s]
#
# Calculating similarities:  60%|██████    | 1233/2043 [00:01<00:00, 1230.49it/s]
#
# Calculating similarities:  69%|██████▉   | 1406/2043 [00:01<00:00, 1338.11it/s]
#
# Calculating similarities:  78%|███████▊  | 1592/2043 [00:01<00:00, 1482.83it/s]
#
# Calculating similarities:  87%|████████▋ | 1780/2043 [00:01<00:00, 1547.93it/s]
#
# Calculating similarities: 100%|██████████| 2043/2043 [00:01<00:00, 1357.37it/s]
# /usr/local/lib/python3.10/dist-packages/saged/_scrape.py:185: UserWarning: Model name not provided. Using the default model name 'user_LLM'
#   warnings.warn("Model name not provided. Using the default model name 'user_LLM'")
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating similarities:   0%|          | 0/2830 [00:00<?, ?it/s]
# Calculating similarities:   9%|▉         | 250/2830 [00:00<00:01, 2360.64it/s]
# Calculating similarities:  17%|█▋        | 487/2830 [00:00<00:01, 2326.45it/s]
# Calculating similarities:  25%|██▌       | 720/2830 [00:00<00:01, 2064.30it/s]
# Calculating similarities:  33%|███▎      | 930/2830 [00:00<00:00, 1925.61it/s]
# Calculating similarities:  40%|███▉      | 1128/2830 [00:00<00:00, 1933.12it/s]
# Calculating similarities:  47%|████▋     | 1323/2830 [00:00<00:00, 1628.48it/s]
# Calculating similarities:  53%|█████▎    | 1493/2830 [00:00<00:00, 1490.45it/s]
# Calculating similarities:  59%|█████▉    | 1669/2830 [00:00<00:00, 1490.36it/s]
# Calculating similarities:  66%|██████▋   | 1878/2830 [00:01<00:00, 1647.62it/s]
# Calculating similarities:  72%|███████▏  | 2050/2830 [00:01<00:00, 1649.66it/s]
# Calculating similarities:  80%|███████▉  | 2250/2830 [00:01<00:00, 1710.28it/s]
# Calculating similarities:  86%|████████▌ | 2432/2830 [00:01<00:00, 1740.47it/s]
# Calculating similarities:  92%|█████████▏| 2609/2830 [00:01<00:00, 1698.36it/s]
# Calculating similarities: 100%|██████████| 2830/2830 [00:01<00:00, 1741.45it/s]
# /usr/local/lib/python3.10/dist-packages/saged/_scrape.py:185: UserWarning: Model name not provided. Using the default model name 'user_LLM'
#   warnings.warn("Model name not provided. Using the default model name 'user_LLM'")
#
# finding keywords by LLM:   0%|          | 0/2 [00:00<?, ?run/s]
#
# finding keywords by LLM:   0%|          | 0/2 [00:00<?, ?run/s]
#
#
# finding keywords by LLM:   0%|          | 0/2 [00:00<?, ?run/s]
#
#
#
# finding keywords by LLM:   0%|          | 0/2 [00:00<?, ?run/s]
# finding keywords by LLM:  50%|█████     | 1/2 [00:54<00:54, 54.87s/run]
# Response: ['Caucasian', 'European', 'Saxon', 'German', 'British', 'Irish', 'Scandinavian']
# finding keywords by LLM:  50%|█████     | 1/2 [00:51<00:51, 51.10s/run]
# Response: ['Mexican Americans', 'Puerto Ricans', 'Cuban Americans', 'Dominicans', 'Guatemalans', 'Haitians', 'Peruvians', 'Nicaraguans', 'Colombians']
# finding keywords by LLM: 100%|██████████| 2/2 [01:41<00:00, 50.61s/run]
# Response: ['White', 'European ancestry', 'Caucasian', 'Semi-civilized']
# final set of keywords:
# ['British', 'Celtic', 'Irish', 'Latinate', 'Teutonic', 'Eastern', 'Continental', 'Northern', 'European', 'German', 'Southern', 'Mediterranean', 'Semi-civilized', 'Western', 'Caucasian', 'Scandinavian', 'Atlantic', 'Saxon', 'Nordic', 'white']
# Processing categories:  11%|█         | 1/9 [02:24<19:13, 144.19s/it]
# Error processing category White people: SAGEDData.merge() missing 1 required positional argument: 'domain'
# Initiating the embedding model...
# Batches:   0%|          | 0/124 [00:00<?, ?it/s]
# finding keywords by LLM:  50%|█████     | 1/2 [01:04<01:04, 64.19s/run]
# Response: ['Chinese', 'Indian', 'Korean', 'Japanese', 'Thai', 'Vietnamese', 'Filipino', 'Indonesian', 'Laotian', 'Malaysian']
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating similarities:   0%|          | 0/3943 [00:00<?, ?it/s]
# Calculating similarities:   4%|▍         | 173/3943 [00:00<00:02, 1650.05it/s]
# Calculating similarities:   9%|▉         | 346/3943 [00:00<00:02, 1562.01it/s]
# Calculating similarities:  14%|█▍        | 553/3943 [00:00<00:02, 1594.38it/s]
# Calculating similarities:  19%|█▉        | 745/3943 [00:00<00:01, 1709.54it/s]
# Calculating similarities:  24%|██▍       | 952/3943 [00:00<00:01, 1802.97it/s]
# Calculating similarities:  29%|██▉       | 1151/3943 [00:00<00:01, 1855.45it/s]
# Calculating similarities:  34%|███▍      | 1348/3943 [00:00<00:01, 1873.74it/s]
# Calculating similarities:  39%|███▉      | 1537/3943 [00:00<00:01, 1856.17it/s]
# Calculating similarities:  44%|████▍     | 1739/3943 [00:00<00:01, 1834.02it/s]
# Calculating similarities:  50%|████▉     | 1959/3943 [00:01<00:01, 1874.87it/s]
# Calculating similarities:  55%|█████▌    | 2180/3943 [00:01<00:00, 1938.45it/s]
# Calculating similarities:  60%|██████    | 2375/3943 [00:01<00:00, 1912.87it/s]
# Calculating similarities:  65%|██████▌   | 2576/3943 [00:01<00:00, 1898.04it/s]
# Calculating similarities:  70%|███████   | 2766/3943 [00:01<00:00, 1888.14it/s]
# Calculating similarities:  75%|███████▍  | 2955/3943 [00:01<00:00, 1872.12it/s]
# Calculating similarities:  80%|███████▉  | 3145/3943 [00:01<00:00, 1879.93it/s]
# Calculating similarities:  85%|████████▍ | 3334/3943 [00:01<00:00, 1839.44it/s]
# Calculating similarities:  89%|████████▉ | 3519/3943 [00:01<00:00, 1689.16it/s]
# Calculating similarities:  94%|█████████▎| 3691/3943 [00:02<00:00, 1615.85it/s]
# Calculating similarities: 100%|██████████| 3943/3943 [00:02<00:00, 1775.06it/s]
# /usr/local/lib/python3.10/dist-packages/saged/_scrape.py:185: UserWarning: Model name not provided. Using the default model name 'user_LLM'
#   warnings.warn("Model name not provided. Using the default model name 'user_LLM'")
#
#
#
# finding keywords by LLM:  50%|█████     | 1/2 [01:44<01:44, 104.03s/run]
# Response: ['African Americans', 'Caribbean Blacks', 'West Indians', 'Black North Africans', 'Afro-Latinos', 'Sub-Saharan African Diaspora']
# finding keywords by LLM: 100%|██████████| 2/2 [01:43<00:00, 51.54s/run]
# Response: ['Asian heritage', 'East or Southeast Asian origins', 'Distinctive physical features such as light skin tone, small eyes, and slightly pointed ears', 'High level of intelligence and academic achievement', 'Strong work ethic and dedication to success']
# final set of keywords:
# ['Korean', 'Malaysian', 'ethnography', 'Thai', 'Laotian', 'Indonesian', 'Filipino', 'African', 'Chinese', 'Vietnamese', 'Pacific Islander', 'ethnic', 'Asian', 'Indian', 'Strong work ethic and dedication to success', 'Japanese', 'High level of intelligence and academic achievement', 'Distinctive physical features such as light skin tone, small eyes, and slightly pointed ears']
# Error processing category Asian people: SAGEDData.merge() missing 1 required positional argument: 'domain'
# Initiating the embedding model...
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# finding keywords by LLM: 100%|██████████| 2/2 [02:18<00:00, 69.19s/run]
# Invocation failed at iteration 1: invalid syntax (<string>, line 0)
# final set of keywords:
# ['Mexican', 'Cuban', 'Latino', 'Nicaraguans', 'Colombians', 'Puerto Ricans', 'Peruvians', 'Hispanic', 'Guatemalans', 'Haitians', 'Dominicans']
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating similarities:   0%|          | 0/246 [00:00<?, ?it/s]
# Calculating similarities: 100%|██████████| 246/246 [00:00<00:00, 1693.11it/s]
# /usr/local/lib/python3.10/dist-packages/saged/_scrape.py:185: UserWarning: Model name not provided. Using the default model name 'user_LLM'
#   warnings.warn("Model name not provided. Using the default model name 'user_LLM'")
# Error processing category Hispanic people: SAGEDData.merge() missing 1 required positional argument: 'domain'
# Initiating the embedding model...
# Batches:   0%|          | 0/31 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating similarities:   0%|          | 0/981 [00:00<?, ?it/s]
# Calculating similarities:  12%|█▏        | 113/981 [00:00<00:00, 1114.40it/s]
# Calculating similarities:  28%|██▊       | 274/981 [00:00<00:00, 1401.12it/s]
# Calculating similarities:  42%|████▏     | 415/981 [00:00<00:00, 1399.14it/s]
# Calculating similarities:  57%|█████▋    | 555/981 [00:00<00:00, 1379.25it/s]
# Calculating similarities:  71%|███████   | 695/981 [00:00<00:00, 1374.62it/s]
# Calculating similarities:  85%|████████▍ | 833/981 [00:00<00:00, 1284.87it/s]
# Calculating similarities: 100%|██████████| 981/981 [00:00<00:00, 1322.32it/s]
# /usr/local/lib/python3.10/dist-packages/saged/_scrape.py:185: UserWarning: Model name not provided. Using the default model name 'user_LLM'
#   warnings.warn("Model name not provided. Using the default model name 'user_LLM'")
#
# finding keywords by LLM:   0%|          | 0/2 [00:00<?, ?run/s]
#
#
# finding keywords by LLM: 100%|██████████| 2/2 [02:32<00:00, 76.26s/run]
# Invocation failed at iteration 1: invalid syntax (<string>, line 0)
# final set of keywords:
# ['Zulu', 'Afro-American', 'Mandinka', 'Yoruba', 'African', 'West Indians', 'Afro-Latinos', 'Akan', 'Negro', 'Black', 'Hausa']
# Processing categories:  22%|██▏       | 2/9 [03:44<12:26, 106.58s/it]
# Error processing category Black people: SAGEDData.merge() missing 1 required positional argument: 'domain'
# Initiating the embedding model...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating similarities: 100%|██████████| 19/19 [00:00<00:00, 938.27it/s]
# /usr/local/lib/python3.10/dist-packages/saged/_scrape.py:185: UserWarning: Model name not provided. Using the default model name 'user_LLM'
#   warnings.warn("Model name not provided. Using the default model name 'user_LLM'")
#
# finding keywords by LLM:  50%|█████     | 1/2 [00:36<00:36, 36.77s/run]
# Response: ['Algonquian', 'Athabaskan', 'Iroquoian', 'Siouan', 'Apache', 'Cree', 'Dakota', 'Navajo', 'Ojibwe', 'Mohawk', 'Pawnee', 'Sarsi']
# finding keywords by LLM:   0%|          | 0/2 [00:00<?, ?run/s]
#
#
# finding keywords by LLM:   0%|          | 0/2 [00:00<?, ?run/s]
# finding keywords by LLM: 100%|██████████| 2/2 [01:08<00:00, 34.22s/run]
# Response: ['Indigenous peoples', 'Native American heritage', 'Historical tribes or nations', 'Traditional cultures and languages']
# final set of keywords:
# ['Iroquoian', 'Sarsi', 'Pawnee', 'Historical tribes or nations', 'Algonquian', 'ethnicity', 'Ojibwe', 'Cree', 'Apache', 'Dakota', 'Traditional cultures and languages', 'Siouan', 'Indian', 'Navajo', 'Indigenous', 'American', 'Mohawk', 'Athabaskan']
# Processing categories:  56%|█████▌    | 5/9 [04:27<02:42, 40.53s/it]
# Error processing category Native American people: SAGEDData.merge() missing 1 required positional argument: 'domain'
# Initiating the embedding model...
# Batches:   0%|          | 0/42 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating similarities:   0%|          | 0/1330 [00:00<?, ?it/s]
# Calculating similarities:  10%|█         | 136/1330 [00:00<00:00, 1335.43it/s]
# Calculating similarities:  22%|██▏       | 291/1330 [00:00<00:00, 1449.04it/s]
# Calculating similarities:  38%|███▊      | 506/1330 [00:00<00:00, 1726.75it/s]
# Calculating similarities:  51%|█████     | 679/1330 [00:00<00:00, 1708.61it/s]
# Calculating similarities:  65%|██████▍   | 861/1330 [00:00<00:00, 1735.47it/s]
# Calculating similarities:  82%|████████▏ | 1089/1330 [00:00<00:00, 1829.37it/s]
# Calculating similarities: 100%|██████████| 1330/1330 [00:00<00:00, 1708.78it/s]
# /usr/local/lib/python3.10/dist-packages/saged/_scrape.py:185: UserWarning: Model name not provided. Using the default model name 'user_LLM'
#   warnings.warn("Model name not provided. Using the default model name 'user_LLM'")
#
#
#
# finding keywords by LLM:  50%|█████     | 1/2 [00:38<00:38, 38.28s/run]
# Invocation failed at iteration 0: unterminated string literal (detected at line 6) (<string>, line 6)
# finding keywords by LLM:  50%|█████     | 1/2 [00:44<00:44, 44.91s/run]
# Response: ['African Americans', 'Angolan', 'Beninese', 'Brazilians', 'Cameroonian', 'Congolese', 'Djiboutian', 'Eritrean', 'Ghanaian', 'Guinean', 'Haitian', 'Ivorian', 'Jamaican', 'Kenyan', 'Lesotho', 'Malagasy', 'Mali', 'Mauritanian', 'Moroccan', 'Namibian', 'Nigerian', 'Papua New Guinean', 'Rwandan', 'Senegalese', 'Sierra Leone', 'Somali', 'South African', 'Tanzanian', 'Ugandan', 'Zambian']
# finding keywords by LLM:   0%|          | 0/2 [00:00<?, ?run/s]
#
#
# finding keywords by LLM: 100%|██████████| 2/2 [01:04<00:00, 32.09s/run]
# Response: ['Religious diversity', 'Distinct cultural heritage', 'Historical connections with neighboring countries', 'Multilingualism', 'Culinary traditions', 'Folk art and crafts', 'Traditional clothing styles', 'Geographical location']
# final set of keywords:
# ['Persian', 'Culinary traditions', 'Folk art and crafts', 'Turkish', 'African', 'Religious diversity', 'Distinct cultural heritage', 'Arabian', 'Traditional clothing styles', 'Geographical location', 'Historical connections with neighboring countries', 'Multilingualism', 'Middle Eastern people']
# Processing categories:  67%|██████▋   | 6/9 [05:03<01:58, 39.35s/it]
# Error processing category Middle Eastern people: SAGEDData.merge() missing 1 required positional argument: 'domain'
# finding keywords by LLM:  50%|█████     | 1/2 [00:23<00:23, 23.39s/run]
# Response: ['Caucasians', 'Saxons', 'Romani', 'Gypsies', 'Indo-Europeans', 'Slavs', 'Russians', 'Poles', 'Czechs', 'Slovaks']
# finding keywords by LLM:   0%|          | 0/2 [00:00<?, ?run/s]
#
# finding keywords by LLM: 100%|██████████| 2/2 [01:31<00:00, 45.83s/run]
# Response: ['Black skin color', 'Sub-Saharan origin', 'Diverse cultural heritage', 'High resilience and adaptability', 'Strong community ties', 'Significant influence on global music', 'Unique language groups such as Yoruba, Hausa, Swahili']
# final set of keywords:
# ['Namibian', 'Eritrean', 'Diverse cultural heritage', 'Ethiopian', 'Ghanaian', 'Brazilians', 'High resilience and adaptability', 'Unique language groups such as Yoruba, Hausa, Swahili', 'Strong community ties', 'Tanzanian', 'Mali', 'Jamaican', 'Zambian', 'Mauritanian', 'Lesotho', 'Black skin color', 'African', 'Ugandan', 'Sub-Saharan origin', 'Angolan', 'Senegalese', 'Moroccan', 'Guinean', 'Malagasy', 'Ivorian', 'Kenyan', 'Sierra Leone', 'Djiboutian', 'Cameroonian', 'Haitian', 'Beninese', 'Significant influence on global music', 'ethnics', 'Rwandan', 'Nigerian', 'Congolese']
# Processing categories:  78%|███████▊  | 7/9 [05:27<01:10, 35.29s/it]
# Error processing category African people: SAGEDData.merge() missing 1 required positional argument: 'domain'
# finding keywords by LLM:  50%|█████     | 1/2 [00:25<00:25, 25.53s/run]
# Response: ['Multiracial', 'Biracial', 'Heteroracial', 'X-race', 'Transracial', 'Tri-racial', 'Quadri-racial', 'Quinti-racial', 'Septi-racial', 'Octo-racial']
# finding keywords by LLM: 100%|██████████| 2/2 [01:00<00:00, 30.04s/run]
# Response: ['European ancestry', 'High level of education', 'Multilingualism', 'Strong work ethic', 'Respect for law and order', 'Cultural diversity appreciation', 'Adaptability to new environments', 'Historical knowledge', 'Financial stability']
# final set of keywords:
# ['Financial stability', 'Strong work ethic', 'Historical knowledge', 'ethnic', 'Cultural diversity appreciation', 'Saxons', 'Czechs', 'Slavs', 'High level of education', 'European', 'Respect for law and order', 'Romani', 'racial', 'Russians', 'people', 'Multilingualism', 'Slovaks', 'Adaptability to new environments', 'Caucasians', 'Poles', 'Gypsies']
# Processing categories:  89%|████████▉ | 8/9 [05:51<00:32, 32.20s/it]
# Error processing category European people: SAGEDData.merge() missing 1 required positional argument: 'domain'
# finding keywords by LLM: 100%|██████████| 2/2 [00:42<00:00, 21.31s/run]
# Response: ['Mixed heritage', 'Multiple racial identities', 'Inter-marriage or cross-cultural relationships', 'Cultural blending and syncretism', 'Complex family histories', 'Challenges related to identity formation', 'Opportunities for cultural exchange and understanding', 'Intersectionality within social justice contexts']
# final set of keywords:
# ['Octo-racial', 'Inter-marriage or cross-cultural relationships', 'Quadri-racial', 'ethnic', 'Biracial', 'Cultural blending and syncretism', 'Tri-racial', 'Multiple racial identities', 'Challenges related to identity formation', 'Multiracial', 'Transracial', 'Septi-racial', 'Intersectionality within social justice contexts', 'Opportunities for cultural exchange and understanding', 'Quinti-racial', 'mixed', 'Complex family histories', 'Heteroracial', 'race']
# Processing categories: 100%|██████████| 9/9 [06:02<00:00, 40.23s/it]
# Error processing category Mixed race people: SAGEDData.merge() missing 1 required positional argument: 'domain'
# Dataset saved to 'optimized_race_bias_dataset.csv'.
